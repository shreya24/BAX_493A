# %%
from google.colab import files

# %%
# !cp '/content/drive/MyDrive/BAX_493_Homeworks/BAX493_FinalProject/TestV2.ipynb' /content/sample_data

# %%
# %run /content/sample_data/TestV2.ipynb

# %%
rapunzel(1)
# Out:
# Rapunzel is a Disney character.
# 3
